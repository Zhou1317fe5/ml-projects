# %%
from nixtlats import TimeGPT

# %%
timegpt = TimeGPT(
    # defaults to os.environ.get("TIMEGPT_TOKEN")
    token = ''
)

# %%
timegpt.validate_token()
# Out:
# INFO:nixtlats.timegpt:Happy Forecasting! :), If you have questions or need support, please email ops@nixtla.io
# True

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Nixtla/transfer-learning-time-series/main/datasets/air_passengers.csv')
df.head()
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# d:\Development\anaconda3\envs\ml\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1318                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1319                           encode_chunked=req.has_header('Transfer-encoding'))
#    1320             except OSError as err: # timeout error
#
# d:\Development\anaconda3\envs\ml\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1251         """Send a complete request to the server."""
# -> 1252         self._send_request(method, url, body, headers, encode_chunked)
#    1253
#
# d:\Development\anaconda3\envs\ml\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1297             body = _encode(body, 'body')
# ...

# %%
timegpt.plot(df, time_col='timestamp', target_col='value')

# %%
timegpt_fcst_df = timegpt.forecast(df=df, h=12, freq='MS', time_col='timestamp', target_col='value')
timegpt_fcst_df.head()
# Out:
# INFO:nixtlats.timegpt:Validating inputs...
# INFO:nixtlats.timegpt:Preprocessing dataframes...
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# d:\Development\anaconda3\envs\ml\lib\site-packages\httpcore\_exceptions.py in map_exceptions(map)
#       9     try:
# ---> 10         yield
#      11     except Exception as exc:  # noqa: PIE786
#
# d:\Development\anaconda3\envs\ml\lib\site-packages\httpcore\_backends\sync.py in connect_tcp(self, host, port, timeout, local_address, socket_options)
#     102                 timeout,
# --> 103                 source_address=source_address,
#     104             )
#
# d:\Development\anaconda3\envs\ml\lib\socket.py in create_connection(address, timeout, source_address)
#     727         try:
# --> 728             raise err
#     729         finally:
#
# ...

# %%
timegpt.plot(df, timegpt_fcst_df, time_col='timestamp', target_col='value')

# %%
timegpt_fcst_df = timegpt.forecast(df=df, h=36, time_col='timestamp', target_col='value', freq='MS')
timegpt_fcst_df.head()
